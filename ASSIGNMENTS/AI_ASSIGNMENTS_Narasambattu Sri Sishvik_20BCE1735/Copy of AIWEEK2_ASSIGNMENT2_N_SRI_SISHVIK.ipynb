# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
#Task1- Read and Preprocess
# Read the CSV file
df = pd.read_csv('drug200.csv')

# %%
# Check for missing values
print(df.isnull().sum())

# Drop rows with missing values
df = df.dropna()


# Check for duplicates
print(df.duplicated().sum())

# Drop duplicates
df = df.drop_duplicates()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64
# 0

# %%
df.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
X = df.iloc[:, 1:6]
Y = df['Age']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state =0)

# %%
X_train.shape
# Out:
# (160, 5)

# %%
X_test.shape
# Out:
# (40, 5)

# %%
Y_train.shape
# Out:
# (160,)

# %%
Y_test.shape
# Out:
# (40,)

# %%
from sklearn.preprocessing import LabelEncoder
     

le = LabelEncoder() # initialize the lib

# %%
X_train['Sex'] = le.fit_transform(X_train['Sex'])
X_train['BP'] = le.fit_transform(X_train['BP'])
X_train['Cholesterol'] = le.fit_transform(X_train['Cholesterol'])
X_train['Drug'] = le.fit_transform(X_train['Drug'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Initializing the seq model
reg_model = Sequential()

# Adding the input layer to the model
reg_model.add(Dense(32,activation='relu'))

# Adding the 2nd hidden layer to the model
reg_model.add(Dense(16,activation='relu'))

# Adding the 3rd hidden layer to the model
reg_model.add(Dense(8,activation='relu'))


# Adding output layer
reg_model.add(Dense(1,activation='sigmoid'))

# %%
# Compile the model
reg_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
reg_model.fit(X_train, Y_train, epochs=20, batch_size=5)
# Out:
# Epoch 1/20
# 32/32 [==============================] - 2s 2ms/step - loss: -173.9388 - accuracy: 0.0000e+00
# Epoch 2/20
# 32/32 [==============================] - 0s 2ms/step - loss: -466.8233 - accuracy: 0.0000e+00
# Epoch 3/20
# 32/32 [==============================] - 0s 2ms/step - loss: -1063.5706 - accuracy: 0.0000e+00
# Epoch 4/20
# 32/32 [==============================] - 0s 2ms/step - loss: -2391.7808 - accuracy: 0.0000e+00
# Epoch 5/20
# 32/32 [==============================] - 0s 2ms/step - loss: -5054.8999 - accuracy: 0.0000e+00
# Epoch 6/20
# 32/32 [==============================] - 0s 2ms/step - loss: -10090.3174 - accuracy: 0.0000e+00
# Epoch 7/20
# 32/32 [==============================] - 0s 2ms/step - loss: -18734.0410 - accuracy: 0.0000e+00
# Epoch 8/20
# 32/32 [==============================] - 0s 2ms/step - loss: -32498.5312 - accuracy: 0.0000e+00
# Epoch 9/20
# 32/32 [==============================] - 0s 2ms/step - loss: -53205.5000 - accuracy: 0.0000e+00
# Epoch 10/20
# 32/32 [==============================] - 0s 2ms/step - loss: -83013.9531 - accuracy: 0.0000e+00
# Epoch 11/20
# 32/32 [==============================] - 0s 2ms/step - loss: -123832.7500 - accuracy: 0.0000e+00
# Epoch 12/20
# 32/32 [==============================] - 0s 2ms/step - loss: -177836.5312 - accuracy: 0.0000e+00
# Epoch 13/20
# 32/32 [==============================] - 0s 3ms/step - loss: -248339.0312 - accuracy: 0.0000e+00
# Epoch 14/20
# 32/32 [==============================] - 0s 2ms/step - loss: -337625.2500 - accuracy: 0.0000e+00
# Epoch 15/20
# 32/32 [==============================] - 0s 2ms/step - loss: -449516.9062 - accuracy: 0.0000e+00
# Epoch 16/20
# 32/32 [==============================] - 0s 2ms/step - loss: -586349.9375 - accuracy: 0.0000e+00
# Epoch 17/20
# 32/32 [==============================] - 0s 2ms/step - loss: -753511.1250 - accuracy: 0.0000e+00
# Epoch 18/20
# 32/32 [==============================] - 0s 2ms/step - loss: -953052.8125 - accuracy: 0.0000e+00
# Epoch 19/20
# 32/32 [==============================] - 0s 2ms/step - loss: -1184963.2500 - accuracy: 0.0000e+00
# Epoch 20/20
# 32/32 [==============================] - 0s 2ms/step - loss: -1461289.6250 - accuracy: 0.0000e+00

# %%
# Testing the model

reg_model.predict([[69,26,65,12,9]])
# Out:
# 1/1 [==============================] - 0s 222ms/step
# array([[1.]], dtype=float32)
